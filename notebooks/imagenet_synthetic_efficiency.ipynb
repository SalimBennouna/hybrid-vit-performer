# %%
# !git clone https://github.com/SalimBennouna/hybrid-vit-performer
# %cd hybrid-vit-performer
# %cd src
# %cd ..

#!pip install performer_pytorch
#!pip install -r requirements.txt
# Out:
# Cloning into 'hybrid-vit-performer'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (344/344), done.
# remote: Compressing objects: 100% (233/233), done.
# remote: Total 344 (delta 131), reused 313 (delta 100), pack-reused 0 (from 0)
# Receiving objects: 100% (344/344), 2.26 MiB | 25.10 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# /content/hybrid-vit-performer/src/hybrid-vit-performer
# /content/hybrid-vit-performer/src/hybrid-vit-performer/src
# /content/hybrid-vit-performer/src/hybrid-vit-performer
# ...

# %%
# %cd ..
# Out:
# /content/hybrid-vit-performer/src/hybrid-vit-performer

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "all_standard",
    "kernel_type": None,
    "m_features": None,
    "device": "cuda",
    "patch_size": 8,
     "epochs": 1,
     "batch_size": 64,
     "num_workers": 2,
     "synthetic_train_samples": 10000,
     "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=True,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=all_standard | Kernel=None | m=None ===
# Epoch 01 | Train Loss 6.963 Acc 0.10% | Test Loss 6.918 Acc 0.10% | Time 136.3s
# Best Test Acc: 0.10%
# Inference: 302.16 ± 40.02 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "all_performer",
    "kernel_type": "relu",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=all_performer | Kernel=relu | m=128 ===
# Epoch 01 | Train Loss 6.961 Acc 0.08% | Test Loss 6.953 Acc 0.15% | Time 89.4s
# Best Test Acc: 0.15%
# Inference: 196.41 ± 26.08 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "all_performer",
    "kernel_type": "softmax",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=all_performer | Kernel=softmax | m=128 ===
# Epoch 01 | Train Loss 6.969 Acc 0.11% | Test Loss 6.951 Acc 0.15% | Time 105.3s
# Best Test Acc: 0.15%
# Inference: 242.56 ± 32.29 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "performer_first",
    "kernel_type": "relu",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=performer_first | Kernel=relu | m=128 ===
# Epoch 01 | Train Loss 6.962 Acc 0.09% | Test Loss 6.962 Acc 0.05% | Time 116.5s
# Best Test Acc: 0.05%
# Inference: 252.26 ± 34.00 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "performer_first",
    "kernel_type": "softmax",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=performer_first | Kernel=softmax | m=128 ===
# Epoch 01 | Train Loss 6.959 Acc 0.09% | Test Loss 6.955 Acc 0.05% | Time 124.0s
# Best Test Acc: 0.05%
# Inference: 272.44 ± 36.22 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "standard_first",
    "kernel_type": "relu",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=standard_first | Kernel=relu | m=128 ===
# Epoch 01 | Train Loss 6.965 Acc 0.07% | Test Loss 6.954 Acc 0.10% | Time 118.7s
# Best Test Acc: 0.10%
# Inference: 254.72 ± 34.70 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "standard_first",
    "kernel_type": "softmax",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=standard_first | Kernel=softmax | m=128 ===
# Epoch 01 | Train Loss 6.968 Acc 0.08% | Test Loss 6.953 Acc 0.20% | Time 125.2s
# Best Test Acc: 0.20%
# Inference: 274.38 ± 36.48 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "intertwined",
    "kernel_type": "relu",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=intertwined | Kernel=relu | m=128 ===
# Epoch 01 | Train Loss 6.967 Acc 0.04% | Test Loss 6.957 Acc 0.05% | Time 117.4s
# Best Test Acc: 0.05%
# Inference: 252.47 ± 33.84 ms / batch

# %%
import sys
sys.path.insert(0, "src")

from hybrid_vit.config import load_config, config_from_dict
from hybrid_vit.experiment import run_single_experiment

cfg_dict = load_config("configs/imagenet_synth.yaml")
cfg_dict.update({
    "dataset": "IMAGENET_SYNTH",
    "architecture": "intertwined",
    "kernel_type": "softmax",
    "m_features": 128,
    "device": "cuda",
    "patch_size": 8,  
    "epochs": 1,
    "batch_size": 64,
    "num_workers": 2,
    "synthetic_train_samples": 10000,
    "synthetic_val_samples": 2000,
})
cfg = config_from_dict(cfg_dict)

_ = run_single_experiment(
    cfg,
    save_dir=None,
    notebook_style_filenames=False,
    is_baseline=False,
)
# Out:
# === Dataset=IMAGENET_SYNTH | Arch=intertwined | Kernel=softmax | m=128 ===
# Epoch 01 | Train Loss 6.965 Acc 0.10% | Test Loss 6.958 Acc 0.15% | Time 124.1s
# Best Test Acc: 0.15%
# Inference: 273.46 ± 36.48 ms / batch
